# %%
from skimage.io import imread,imshow,imsave
#https://www.youtube.com/channel/UCbBZNHYHOte25t8o2aHZRPg

# %%
zahoor=imread('WhatsApp-Image-2021-12-06-at-8.59.13-PM.jpeg')

# %%
from matplotlib import pyplot as plt

# %%
plt.figure()

# %%
imshow(zahoor)

# %%
# %matplotlib notebook
imshow(zahoor)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
imsave('zahoor.jpeg',im)

# %%
im_color=imread('zahoor.jpeg')
im_gray=imread('walking.jpg')

# %%
im_color.shape
#since color image so  height*width*(RGB). IF there is 4 instead of 3 it means RGBA. A=alpha
# Out:
# (794, 794, 3)

# %%
im_gray.shape
#hight*width
# Out:
# (799, 640)

# %%
im_color.max()
# Out:
# 255

# %%
im_gray.max()
# Out:
# 255

# %%
#to find the value of pixel at specific region, use f(y,x)
print(im_color[700,100])
# Out:
# [244 243 248]
